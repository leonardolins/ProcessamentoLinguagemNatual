# %% [markdown]
# # **Primeiro contato com nltk**

# %%
# primeiro contato com nltk

# %% [markdown]
# **Primeiro instalamos**

# %%
#!pip install nltk

# %% [markdown]
#  **importamos os recursos**

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/LeonardoLins/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# **Um texto qualquer**

# %%
my_text = "Hi Mr. Smith! I’m going to buy some vegetables (tomatoes and cucumbers) from the store. Should I pick up some black-eyed peas as well?"

# %%
print(word_tokenize(my_text))
# Out:
# ['Hi', 'Mr.', 'Smith', '!', 'I', '’', 'm', 'going', 'to', 'buy', 'some', 'vegetables', '(', 'tomatoes', 'and', 'cucumbers', ')', 'from', 'the', 'store', '.', 'Should', 'I', 'pick', 'up', 'some', 'black-eyed', 'peas', 'as', 'well', '?']

# %% [markdown]
# **Agora em portugues**

# %%
meu_texto = "Caneta azul, azul caneta Caneta azul tá marcada com minhas letra Caneta azul, azul caneta Caneta azul tá marcada com minhas letra"

# %%
print(word_tokenize(meu_texto))
# Out:
# ['Caneta', 'azul', ',', 'azul', 'caneta', 'Caneta', 'azul', 'tá', 'marcada', 'com', 'minhas', 'letra', 'Caneta', 'azul', ',', 'azul', 'caneta', 'Caneta', 'azul', 'tá', 'marcada', 'com', 'minhas', 'letra']

# %% [markdown]
# **Agora um texto representativo**

# %%
noticia = "Faltando pouco mais de duas semanas para os eleitores irem às urnas no dia 15 de novembro, pesquisa Ibope divulgada nesta sexta-feira indicou uma redução no percentual dos cariocas que não têm candidato, além de um afunilamento na disputa por vaga no segundo turno da eleição à prefeitura do Rio. O percentual de brancos e nulos agora é de 15%, uma queda de oito pontos em relação ao levantamento anterior, divulgado há duas semanas. Já os que não souberam ou não quiseram opinar seguem em 5%.Na última semana, pesquisa Datafolha já havia apontado tendência semelhante: apenas um quinto (20%) dos entrevistados pelo instituto não declarou voto em nenhum candidato, somando brancos, nulos e indecisos na modalidade estimulada, isto é, quando o entrevistador apresenta os nomes de todos os concorrentes.Na pesquisa espontânea do Ibope, em que o eleitor é perguntado sobre quem vota sem ser apresentado a nenhum nome, 27% não souberam ou não quiseram apontar nenhum candidato no levantamento divulgado nesta sexta-feira. Na pesquisa anterior, divulgada no dia 15, o percentual era de 30%. Votos brancos e nulos também apresentaram queda, saindo de 27% para 23% na modalidade espontânea. Eduardo Paes (DEM) segue na liderança, de acordo com o Ibope, com um empate numérico na segunda colocação entre Marcelo Crivella (Republicanos) e Martha Rocha (PDT). A candidata do PDT, que cresceu seis pontos em relação ao levantamento anterior, foi a única a avançar acima da margem de erro, que é de três pontos percentuais. Crivella e Martha, ambos com 14%, seguem tecnicamente empatados com Benedita da Silva (PT), que aparece com 9%. Embora tenha oscilado positivamente dois pontos, a petista viu sua desvantagem para Martha aumentar para quatro pontos, ficando mais distante de uma vaga no segundo turno.aes e Crivella oscilaram dois pontos para cima cada um nas intenções de voto, e também experimentaram variações negativas de dois pontos em suas taxas de rejeição. O atual prefeito segue sendo o mais rejeitado, com 55%, enquanto Paes aparece com 28%, agora numericamente atrás de Benedita, que se manteve com 29%. A rejeição de Martha Rocha, por outro lado, passou de 9% para 11%. A candidata do PDT vem sendo alvo de ataques recentes por parte das campanhas de Paes e Crivella."

# %%
print(word_tokenize(noticia))
# Out:
# ['Faltando', 'pouco', 'mais', 'de', 'duas', 'semanas', 'para', 'os', 'eleitores', 'irem', 'às', 'urnas', 'no', 'dia', '15', 'de', 'novembro', ',', 'pesquisa', 'Ibope', 'divulgada', 'nesta', 'sexta-feira', 'indicou', 'uma', 'redução', 'no', 'percentual', 'dos', 'cariocas', 'que', 'não', 'têm', 'candidato', ',', 'além', 'de', 'um', 'afunilamento', 'na', 'disputa', 'por', 'vaga', 'no', 'segundo', 'turno', 'da', 'eleição', 'à', 'prefeitura', 'do', 'Rio', '.', 'O', 'percentual', 'de', 'brancos', 'e', 'nulos', 'agora', 'é', 'de', '15', '%', ',', 'uma', 'queda', 'de', 'oito', 'pontos', 'em', 'relação', 'ao', 'levantamento', 'anterior', ',', 'divulgado', 'há', 'duas', 'semanas', '.', 'Já', 'os', 'que', 'não', 'souberam', 'ou', 'não', 'quiseram', 'opinar', 'seguem', 'em', '5', '%', '.Na', 'última', 'semana', ',', 'pesquisa', 'Datafolha', 'já', 'havia', 'apontado', 'tendência', 'semelhante', ':', 'apenas', 'um', 'quinto', '(', '20', '%', ')', 'dos', 'entrevistados', 'pelo', 'instituto', 'não',
# ...

# %% [markdown]
# **Stop words**

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/LeonardoLins/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stopWords_list = list(stopwords.words('portuguese'))

# %%
words = word_tokenize(noticia)

# %%
print(stopWords_list)
# Out:
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'est
# ...

# %%
clean_words = [word for word in words if not (word in stopWords_list)]

# %%
print(clean_words)
# Out:
# ['Faltando', 'pouco', 'duas', 'semanas', 'eleitores', 'irem', 'urnas', 'dia', '15', 'novembro', ',', 'pesquisa', 'Ibope', 'divulgada', 'nesta', 'sexta-feira', 'indicou', 'redução', 'percentual', 'cariocas', 'têm', 'candidato', ',', 'além', 'afunilamento', 'disputa', 'vaga', 'segundo', 'turno', 'eleição', 'prefeitura', 'Rio', '.', 'O', 'percentual', 'brancos', 'nulos', 'agora', '15', '%', ',', 'queda', 'oito', 'pontos', 'relação', 'levantamento', 'anterior', ',', 'divulgado', 'duas', 'semanas', '.', 'Já', 'souberam', 'quiseram', 'opinar', 'seguem', '5', '%', '.Na', 'última', 'semana', ',', 'pesquisa', 'Datafolha', 'havia', 'apontado', 'tendência', 'semelhante', ':', 'apenas', 'quinto', '(', '20', '%', ')', 'entrevistados', 'instituto', 'declarou', 'voto', 'nenhum', 'candidato', ',', 'somando', 'brancos', ',', 'nulos', 'indecisos', 'modalidade', 'estimulada', ',', ',', 'entrevistador', 'apresenta', 'nomes', 'todos', 'concorrentes.Na', 'pesquisa', 'espontânea', 'Ibope', ',', 'eleitor', 
# ...

# %%
from collections import Counter

# Converte a lista em um dicionário com contagem de valores
word_counts_clean = Counter(clean_words)
clean = word_counts_clean

# %%
word_counts_clean
# Out:
# Counter({'Faltando': 1,
#          'pouco': 1,
#          'duas': 2,
#          'semanas': 2,
#          'eleitores': 1,
#          'irem': 1,
#          'urnas': 1,
#          'dia': 2,
#          '15': 3,
#          'novembro': 1,
#          ',': 31,
#          'pesquisa': 4,
#          'Ibope': 3,
#          'divulgada': 2,
#          'nesta': 2,
#          'sexta-feira': 2,
#          'indicou': 1,
#          'redução': 1,
#          'percentual': 3,
#          'cariocas': 1,
#          'têm': 1,
#          'candidato': 3,
#          'além': 1,
#          'afunilamento': 1,
#          'disputa': 1,
#          'vaga': 2,
#          'segundo': 2,
#          'turno': 1,
#          'eleição': 1,
#          'prefeitura': 1,
#          'Rio': 1,
#          '.': 12,
#          'O': 2,
#          'brancos': 3,
#          'nulos': 3,
#          'agora': 2,
#          '%': 14,
#          'queda': 2,
#          'oito': 1,
#          'pontos': 7,
#          'relação': 2,
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = clean_words
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).fit_words(clean)
#wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
